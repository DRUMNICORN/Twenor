# %%
from src.core.Computerization import Computerization
comp = Computerization(data_dir='DnB-Genres', seconds = 3, batch_size = 64)
comp.loadDataFrameFile()

comp.dropMissingLabel('Crossbread')
comp.dropMissingLabel('Else')
comp.dropMissingLabel('Drumstep')

comp.generateInformation()
# Out:
# TF version:- 2.8.0
# Data Directory: data\DnB-Genres
# Dataset has (10000, 82)
# Count of Positive and Negative samples
# Columns with NA values are []
# Expected duration is {66150.0}
# Columns with DIFFRENT values are []
#         index  label
# 0       Break   1000
# 1  Dancefloor   1000
# 2        Deep   1000
# 3      JumpUp   1000
# 4      Jungle   1000
# 5      Liquid   1000
# 6     Minimal   1000
# 7   Neurofunk   1000
# 8     Sambass   1000
# 9      Shriek   1000
#                         filename  chroma_stft10_mean  chroma_stft10_var  \
# 0  AcdBrnOut_-_Like_A_Bitch0.mp3            0.009765           0.057632
# 1  AcdBrnOut_-_Like_A_Bitch1.mp3            0.002278           0.034889
# 2  AcdBrnOut_-_Like_A_Bitch2.mp3           -0.023303           0.039682
# 3  AcdBrnOut_-_Like_A_Bitch3.mp3            0.016674           0.030656
# 4  AcdBrnOut_-_Like_A_Bitch4.mp3           -0.004426           0.038543
#
#    chroma_stft11_mean  chroma_stft11_var  chroma_stft12_mean  \
# ...

# %%
comp.preperation()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\robin\.mega\Coding\Python\Genre-Classification\3. Train your Model.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/3.%20Train%20your%20Model.ipynb#ch0000001?line=0'>1</a> comp.preperation()
#
# File c:\Users\robin\.mega\Coding\Python\Genre-Classification\src\core\Computerization.py:31, in Computerization.preperation(self)
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/core/Computerization.py?line=29'>30</a> def preperation(self):
# ---> <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/core/Computerization.py?line=30'>31</a>     self.df.drop(['length', 'index'], axis=1, inplace=True)
# ...

# %%
comp.buildModelA()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 256)               20480
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 6)                 390
#
# ...
# Total params: 62,022
# Trainable params: 62,022
# Non-trainable params: 0
# _________________________________________________________________
# None
# STRUCT Index(['chroma_stft10_mean', 'chroma_stft10_var', 'chroma_stft11_mean',
#        'chroma_stft11_var', 'chroma_stft12_mean', 'chroma_stft12_var',
#        'chroma_stft1_mean', 'chroma_stft1_var', 'chroma_stft2_mean',
#        'chroma_stft2_var', 'chroma_stft3_mean', 'chroma_stft3_var',
#        'chroma_stft4_mean', 'chroma_stft4_var', 'chroma_stft5_mean',
#        'chroma_stft5_var', 'chroma_stft6_mean', 'chroma_stft6_var',
# ...

# %%
comp.buildModelB()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 512)               40960
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 6)                 390
#
# ...
# Total params: 213,830
# Trainable params: 213,830
# Non-trainable params: 0
# _________________________________________________________________
# None
# STRUCT Index(['chroma_stft10_mean', 'chroma_stft10_var', 'chroma_stft11_mean',
# ...

# %%
comp.buildModelC()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 512)               40960
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_10 (Dense)            (None, 256)               131328
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 128)               32896
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 6)                 390
#
# ...
# Total params: 213,830
# Trainable params: 213,830
# Non-trainable params: 0
# _________________________________________________________________
# None
# STRUCT Index(['chroma_stft10_mean', 'chroma_stft10_var', 'chroma_stft11_mean',
# ...

# %%
comp.buildModelD()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_14 (Dense)            (None, 1024)              81920
#
#  dropout_8 (Dropout)         (None, 1024)              0
#
#  dense_15 (Dense)            (None, 512)               524800
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_16 (Dense)            (None, 256)               131328
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 128)               32896
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_18 (Dense)            (None, 64)                8256
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 6)                 390
#
# ...
# Total params: 779,590
# Trainable params: 779,590
# Non-trainable params: 0
# _________________________________________________________________
# ...

# %%
comp.buildModelE()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_20 (Dense)            (None, 512)               40960
#
#  dropout_13 (Dropout)        (None, 512)               0
#
#  dense_21 (Dense)            (None, 256)               131328
#
#  dropout_14 (Dropout)        (None, 256)               0
#
#  dense_22 (Dense)            (None, 128)               32896
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_23 (Dense)            (None, 64)                8256
#
#  dropout_16 (Dropout)        (None, 64)                0
#
#  dense_24 (Dense)            (None, 6)                 390
#
# ...
# Total params: 213,830
# Trainable params: 213,830
# Non-trainable params: 0
# _________________________________________________________________
# None
# STRUCT Index(['chroma_stft10_mean', 'chroma_stft10_var', 'chroma_stft11_mean',
# ...

# %%
comp.generateHistory()
# Out:
# Model 0: Max. Validation Accuracy is 0.8920833468437195%
# Model 1: Max. Validation Accuracy is 0.9179166555404663%
# Model 2: Max. Validation Accuracy is 0.8974999785423279%
# Model 3: Max. Validation Accuracy is 0.9279166460037231%
# Model 4: Max. Validation Accuracy is 0.9179166555404663%

# %%
comp.save()
# Out:
# best model is 3
