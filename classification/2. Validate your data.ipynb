# %%
from src.core.Validation import Validation
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# %matplotlib inline

# %%
val = Validation(data_dir='DnB-Genres',seconds = 3)
val.loadDataFrameFile()
# val.df.drop([''], axis=1)
val.dropMissingLabel('Crossbread')
val.dropMissingLabel('Else')
val.dropMissingLabel('Drumstep')
# val.normalizeDataFrame()

val.generateBPMPlot()
val.generateInformation()
# val.generateImportancePlot()
# val.generateMissingValues()
val.generateHeadMapVar()
val.generateHeadMapMean()
val.generateOldPCACharts()
# Out:
# Data Directory: data\DnB-Genres
# Dataset has (9280, 82)
# Count of Positive and Negative samples
# Columns with NA values are []
# Expected duration is {66150.0}
# Columns with DIFFRENT values are []
#         index  label
# 0       Break   1000
# 1  Dancefloor   1000
# 2        Deep   1000
# 3      Jumpup   1000
# 4      Jungle   1000
# 5      Liquid   1000
# 6     Minimal   1000
# 7   Neurofunk   1000
# 8     Sambass   1000
# 9    Drumstep    280
#                         filename  chroma_stft10_mean  chroma_stft10_var  \
# 0  AcdBrnOut_-_Like_A_Bitch0.mp3            0.009765           0.057632
# 1  AcdBrnOut_-_Like_A_Bitch1.mp3            0.002278           0.034889
# 2  AcdBrnOut_-_Like_A_Bitch2.mp3           -0.023303           0.039682
# 3  AcdBrnOut_-_Like_A_Bitch3.mp3            0.016674           0.030656
# 4  AcdBrnOut_-_Like_A_Bitch4.mp3           -0.004426           0.038543
#
#    chroma_stft11_mean  chroma_stft11_var  chroma_stft12_mean  \
# 0            0.023603           0.179198            0.011574
# 1            0.008783           0.207258            0.009379
# 2           -0.066435           0.145591           -0.011805
# 3            0.063979           0.140526            0.013014
# 4            0.034967           0.189867            0.007864
#
#    chroma_stft12_var  chroma_stft1_mean  chroma_stft1_var  chroma_stft2_mean  \
# 0           0.118252          -0.043367          0.743633           0.015234
# 1           0.104837          -0.007028          0.791296          -0.006323
# 2           0.115387           0.166232          0.796088          -0.019387
# 3           0.103107          -0.175065          0.751999           0.036636
# 4           0.108070          -0.045725          0.793141           0.014579
#
#    ...  mfcc_perc9_var  rms_mean   rms_var  spectral_contrast_mean  \
# 0  ...    22130.484513  0.114719  0.001023               22.031523
# 1  ...    22347.497532  0.116436  0.000634               22.107451
# 2  ...    24725.953333  0.117166  0.000637               22.066505
# 3  ...    22637.630510  0.120403  0.000675               21.897726
# 4  ...    22251.551577  0.119014  0.000752               22.097192
#
#    spectral_contrast_var  tempo  tonnetz_mean  tonnetz_var  \
# 0              51.670078  172.0      0.166621     0.029944
# 1              54.401293  117.0      0.166797     0.029507
# 2              54.076595  117.0      0.163430     0.029087
# 3              52.448079  117.0      0.168455     0.029406
# 4              49.514967  117.0      0.169481     0.028976
#
#    zero_crossing_rate_mean  zero_crossing_rate_var
# 0                 0.016061                0.000273
# 1                 0.013792                0.000022
# 2                 0.013480                0.000023
# 3                 0.013093                0.000020
# 4                 0.013007                0.000019
#
# [5 rows x 82 columns]
# 82
